# %% [markdown]
# ## 1. 자소서 문항을 끌어오기

# %%
# pip install -U selenium webdriver-manager
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

opts = webdriver.ChromeOptions()
opts.add_argument("--headless=new")
opts.add_argument("--no-sandbox")
opts.add_argument("--disable-dev-shm-usage")
opts.add_argument("--window-size=1920,1080")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                          options=opts)
driver.get("https://www.naver.com")
print(driver.title)
driver.quit()
# Out:
# ----------------------------------------------------------------
# WebDriverException             Traceback (most recent call last)
# Cell In[5], line 12
#       9 opts.add_argument("--disable-dev-shm-usage")
#      10 opts.add_argument("--window-size=1920,1080")
# ---> 12 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
#      13                           options=opts)
#      14 driver.get("https://www.naver.com")
#      15 print(driver.title)
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/chromium/webdriver.py:71, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      62 executor = ChromiumRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     browser_name=browser_name,
#    (...)     67     ignore_proxy=options._ignore_local_proxy,
#      68 )
#      70 try:
# ---> 71     super().__init__(command_executor=executor, options=options)
#      72 except Exception:
#      73     self.quit()
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:263, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     261 self._authenticator_id = None
#     262 self.start_client()
# --> 263 self.start_session(capabilities)
#     264 self._fedcm = FedCM(self)
#     266 self._websocket_connection = None
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:366, in WebDriver.start_session(self, capabilities)
#     364 caps = _create_caps(capabilities)
#     365 try:
# --> 366     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     367     self.session_id = response.get("sessionId")
#     368     self.caps = response.get("capabilities")
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: cannot find Chrome binary
# Stacktrace:
# #0 0x556ba51084e3 <unknown>
# #1 0x556ba4e37c76 <unknown>
# #2 0x556ba4e5e757 <unknown>
# #3 0x556ba4e5d029 <unknown>
# #4 0x556ba4e9bccc <unknown>
# #5 0x556ba4e9b47f <unknown>
# #6 0x556ba4e92de3 <unknown>
# #7 0x556ba4e682dd <unknown>
# #8 0x556ba4e6934e <unknown>
# #9 0x556ba50c83e4 <unknown>
# #10 0x556ba50cc3d7 <unknown>
# #11 0x556ba50d6b20 <unknown>
# #12 0x556ba50cd023 <unknown>
# #13 0x556ba509b1aa <unknown>
# #14 0x556ba50f16b8 <unknown>
# #15 0x556ba50f1847 <unknown>
# #16 0x556ba5101243 <unknown>
# #17 0x7f49a7b44ac3 <unknown>

# %%
# pip install selenium webdriver-manager

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
# 서버/도커/Colab 류 환경이면 아래 3줄 추가
# options.add_argument("--headless=new")
# options.add_argument("--no-sandbox")
# options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                          options=options)

driver.get("https://www.naver.com")
print(driver.title)

driver.quit()
# Out:
# ----------------------------------------------------------------
# WebDriverException             Traceback (most recent call last)
# Cell In[3], line 15
#       9 options.add_argument("--start-maximized")
#      10 # 서버/도커/Colab 류 환경이면 아래 3줄 추가
#      11 # options.add_argument("--headless=new")
#      12 # options.add_argument("--no-sandbox")
#      13 # options.add_argument("--disable-dev-shm-usage")
# ---> 15 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
#      16                           options=options)
#      18 driver.get("https://www.naver.com")
#      19 print(driver.title)
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/chromium/webdriver.py:71, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      62 executor = ChromiumRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     browser_name=browser_name,
#    (...)     67     ignore_proxy=options._ignore_local_proxy,
#      68 )
#      70 try:
# ---> 71     super().__init__(command_executor=executor, options=options)
#      72 except Exception:
#      73     self.quit()
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:263, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     261 self._authenticator_id = None
#     262 self.start_client()
# --> 263 self.start_session(capabilities)
#     264 self._fedcm = FedCM(self)
#     266 self._websocket_connection = None
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:366, in WebDriver.start_session(self, capabilities)
#     364 caps = _create_caps(capabilities)
#     365 try:
# --> 366     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     367     self.session_id = response.get("sessionId")
#     368     self.caps = response.get("capabilities")
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: cannot find Chrome binary
# Stacktrace:
# #0 0x5583b4abb4e3 <unknown>
# #1 0x5583b47eac76 <unknown>
# #2 0x5583b4811757 <unknown>
# #3 0x5583b4810029 <unknown>
# #4 0x5583b484eccc <unknown>
# #5 0x5583b484e47f <unknown>
# #6 0x5583b4845de3 <unknown>
# #7 0x5583b481b2dd <unknown>
# #8 0x5583b481c34e <unknown>
# #9 0x5583b4a7b3e4 <unknown>
# #10 0x5583b4a7f3d7 <unknown>
# #11 0x5583b4a89b20 <unknown>
# #12 0x5583b4a80023 <unknown>
# #13 0x5583b4a4e1aa <unknown>
# #14 0x5583b4aa46b8 <unknown>
# #15 0x5583b4aa4847 <unknown>
# #16 0x5583b4ab4243 <unknown>
# #17 0x7fd216250ac3 <unknown>

# %% [markdown]
# ## 2. 채용공고 크롤링으로 저장 되는지
